# %%
# 정답
def solution(numbers, hand):
    answer = ""
    left_number = 10
    right_number = 12
    for i in numbers:
        if i == 1 or i == 4 or i == 7:
            left_number = i
            answer += 'L'
        elif i == 3 or i == 6 or i == 9:
            right_number = i
            answer += 'R'
        else:
            if i == 0:
                i =11
            left_move = abs(i - left_number)
            right_move = abs(i - right_number)
            
            if left_move == 0:
                answer += 'L'
            elif right_move == 0:
                answer += 'R'
                
            elif hand == "left":
                if left_move == 1 or left_move == 3 :
                    left_number = i
                    answer += "L"
                elif left_move == 2 or left_move == 4 or left_move == 6:
                    if right_move == 1 or right_move == 3:
                        right_number = i
                        answer += "R"
                    else:
                        left_number = i 
                        answer += "L"
                elif left_move == 5 or left_move == 7 or left_move == 9:
                    if right_move == 10 or right_move == 8 or right_move == 5 or right_move == 7 or right_move ==9 :
                        left_number = i
                        answer += "L"
                    else:
                        right_number = i
                        answer += "R"
                else:
                    if right_move != 10 and right_move != 8:
                        right_number = i
                        answer += "R"
                    else:
                        left_number = i
                        answer += 'L'

            else:
                if right_move == 1 or right_move == 3:
                    right_number = i
                    answer += "R"
                elif right_move == 2 or right_move == 4 or right_move == 6:
                    if left_move == 1 or left_move == 3:
                        left_number = i
                        answer += "L"
                    else:
                        right_number = i
                        answer += "R"
                elif right_move == 5 or right_move == 7 or right_move == 9:
                    if left_move == 10 or left_move == 8 or left_move == 5 or left_move == 7 or left_move == 9:
                        right_number = i
                        answer += "R"
                    else:
                        left_number = i
                        answer += "L"
                else:
                    if left_move != 10 and left_move != 8:
                        left_number = i
                        answer += 'L'
                    else:
                        right_number = i
                        answer += 'R'
    return answer

# %%
# 대각선 이동이 가능할 때
def solution(numbers, hand):
    answer = ""
    left_number = 10
    right_number = 12
    for i in numbers:
        if i == 1 or i == 4 or i == 7:
            left_number = i
            answer += 'L'
        elif i == 3 or i == 6 or i == 9:
            right_number = i
            answer += 'R'
        else:
            if i == 0:
                i =11
            left_move = abs(i - left_number)
            right_move = abs(i - right_number)
            
            if left_move == 0:
                answer += 'L'
            elif right_move == 0:
                answer += 'R'
                
            elif hand == "left":
                if left_move == 1 or left_move == 3 :
                    left_number = i
                    answer += "L"
                elif left_move == 2 or left_move == 4:
                    if right_move == 1 or right_move == 3:
                        right_number = i
                        answer += "R"
                    else:
                        left_number = i 
                        answer += "L"
                elif left_move == 6:
                    if right_move != 1 and right_move != 2 and  right_move != 3 and right_move != 4:
                        left_number = i
                        answer += 'L'
                    else:
                        right_number = i
                        answer += "R"
                elif left_move == 5 or left_move == 7 :
                    if right_move == 8 or right_move == 9 or right_move == 10 :
                        left_number = i
                        answer += "L"
                    else:
                        right_number = i
                        answer += "R"
                elif left_move == 9: 
                    if right_number == 8 or right_number ==10:
                        left_number = i
                        answer += "L"
                    else:
                        right_number = i
                        answer += 'R'
                else:
                    if right_move != 8 and right_move != 10:
                        right_number = i
                        answer += 'R'
                    else:
                        left_number = i
                        answer += 'L'

            else:
                if right_move == 1 or right_move == 3:
                    right_number = i
                    answer += "R"
                elif right_move == 2 or right_move == 4:
                    if left_move == 1 or left_move == 3:
                        left_number = i
                        answer += "L"
                    else:
                        right_number = i
                        answer += "R"
                elif right_move == 6:
                    if left_move != 1 and left_move != 2 and  left_move != 3 and left_move != 4:
                        right_number = i
                        answer += 'R'
                    else:
                        left_number =i
                        answer += 'L'
                elif right_move == 5 or right_move == 7:
                    if left_move == 8 or left_move == 9 or left_move == 10:
                        right_number = i
                        answer += "R"
                    else:
                        left_number = i
                        answer += "L"
                elif right_move ==9:
                    if left_move == 8 or left_move ==10:
                        right_number = i
                        answer += 'R'
                    else:
                        left_number = i
                        answer += 'L'
                else:
                    if left_move != 10 and left_move != 8:
                        left_number = i
                        answer += 'L'
                    else:
                        right_number = i
                        answer += 'R'
    return answer
